# %%
import urllib
url = 'https://drive.google.com/file/d/1K_DnJVxdS_T3Sel5LWDrJsqPUZuB3Hvq/view?usp=sharing'

file = urllib.request.urlopen(url)

# %%
import pandas as pd

# %%
df = pd.read_excel('online_merged.xlsx', sheet_name='merged')

# %%
df
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 0        493414     21844                   RETRO SPOT MUG        36
# 1        493414     21533        RETRO SPOT LARGE MILK JUG        12
# 2        493414     37508  NEW ENGLAND CERAMIC CAKE SERVER         2
# 3        493414    35001G             HAND OPEN SHAPE GOLD         2
# 4        493414     21527   RETRO SPOT TRADITIONAL TEAPOT         12
# ...         ...       ...                              ...       ...
# 770687   581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 770688   581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 770689   581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 770690   581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 770691   581587      POST                          POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# 0      2010-01-04 10:28:00   2.55        14590  United Kingdom
# ...
